# %%
# install pytorch 
# !pip install --pre torch torchvision torchaudio -f https://download.pytorch.org/whl/nightly/cu102/torch_nightly.html -U

# %%
# test torch version and CUDA device
import torch
print(torch.__version__)
a = torch.Tensor([1]).cuda()
print(a)
# Out:
# 1.9.0
# tensor([1.], device='cuda:0')

# %%
# mount google drive
# from google.colab import drive
# drive.mount("/content/gdrive")

# %%
# # change to project home directory
# import os
# os.chdir("/content/gdrive/My Drive/object_detection_frcnn_mscoco_boilerplate")

# %%
pwd
# Out:
# '/home/hasan/Downloads/AidUI/object_detection/object_detection_frcnn_mscoco_boilerplate'

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torchvision
from torchvision import datasets, transforms, models
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

# %%
import utils

# %%
import pprint
pp = pprint.PrettyPrinter()
import json

# %%
# path to data and annotation
data_dir = 'inference_data'

# %%
test_transforms = transforms.Compose([transforms.Resize(224),
                                      transforms.ToTensor(),
                                      #transforms.Normalize([0.485, 0.456, 0.406],
                                      #                     [0.229, 0.224, 0.225])
                                     ])
dataset_test = datasets.ImageFolder(data_dir, transform=test_transforms)

# %%
data_loader_test = torch.utils.data.DataLoader(
    dataset_test, batch_size=1, shuffle=False, num_workers=1,
    collate_fn=utils.collate_fn)

# %%
# select device (whether GPU or CPU)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
num_classes = 6

# %%
model = torchvision.models.detection.fasterrcnn_resnet50_fpn()
in_features = model.roi_heads.box_predictor.cls_score.in_features
model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)
model.load_state_dict(torch.load('trained-visual-cue-detection-model.pth'))
# Out:
# <All keys matched successfully>

# %%
model.eval()
# Out:
# FasterRCNN(
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#       Resize(min_size=(800,), max_size=1333, mode='bilinear')
#   )
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(256, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(512, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(1024, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(2048, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (fpn): FeaturePyramidNetwork(
#       (inner_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         (3): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (layer_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (extra_blocks): LastLevelMaxPool()
#     )
#   )
#   (rpn): RegionProposalNetwork(
#     (anchor_generator): AnchorGenerator()
#     (head): RPNHead(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (cls_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (bbox_pred): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): RoIHeads(
#     (box_roi_pool): MultiScaleRoIAlign(featmap_names=['0', '1', '2', '3'], output_size=(7, 7), sampling_ratio=2)
#     (box_head): TwoMLPHead(
#       (fc6): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc7): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNPredictor(
#       (cls_score): Linear(in_features=1024, out_features=6, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=24, bias=True)
#     )
#   )
# )

# %%
print("================= INFERENCE ===========================")
with torch.no_grad():
    correct = 0
    total = 0
    inference_result = {}
    # for images, labels in data_loader_test:
    for i, (images, labels) in enumerate(data_loader_test, 0):
        print("================== batch ==================")
        sample_fname, _ = data_loader_test.dataset.samples[i]
        filename = sample_fname.split("/")[2]
        print("filename: ", filename)
        outputs = model(images)
        print("outputs")
        pp.pprint(outputs)

        # init boxes, labels, scores
        boxes = None
        labels = None
        scores = None
        
        # get boxes, labels, scores
        if len(outputs[0]["boxes"]) != 0:
          boxes = outputs[0]["boxes"][0].numpy().tolist()
        if len(outputs[0]["labels"]) != 0:
          labels = outputs[0]["labels"][0].numpy().tolist()
        if len(outputs[0]["scores"]) != 0:
          scores = outputs[0]["scores"][0].numpy().tolist()
        
        # populate JSON
        inference_result["boxes"] = boxes
        inference_result["labels"] = labels
        inference_result["scores"] = scores

        print("inference result")
        pp.pprint(inference_result)

        # write inference result
        inference_output_dir = "./inference_output/"
        inference_output_filename = inference_output_dir + filename.split(".")[0] + ".json"
        with open(inference_output_filename, "w") as fp:
          json.dump(inference_result, fp)
        fp.close()
        # break
# Out:
# ================= INFERENCE ===========================
# ================== batch ==================
# filename:  (146)www.sivanaspirit.com_96c5.jpg
# /home/hasan/anaconda3/envs/dl_dp_obj_det_env/lib/python3.8/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /opt/conda/conda-bld/pytorch_1623448234945/work/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (159)www.victorianplumbing.co.uk_62cc.jpg
# outputs
# [{'boxes': tensor([[177.4770, 177.6239, 240.4615, 209.7444]]),
#   'labels': tensor([5]),
#   'scores': tensor([0.0970])}]
# inference result
# {'boxes': [177.4770050048828,
#            177.62393188476562,
#            240.4614715576172,
#            209.74440002441406],
#  'labels': 5,
#  'scores': 0.09698802977800369}
# ================== batch ==================
# filename:  (170)shapermint.com_fcf2.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (177)www.adoreme.com_a719.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (194)www.dressbarn.com_30d1.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (196)www.epicsports.com_5905.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (218)www.naturehills.com_8b1a.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (23)nutrabay.com_5665.jpg
# outputs
# [{'boxes': tensor([[49.6827, 67.4999, 90.2945, 81.2742]]),
#   'labels': tensor([5]),
#   'scores': tensor([0.0891])}]
# inference result
# {'boxes': [49.68269729614258,
#            67.49992370605469,
#            90.29454040527344,
#            81.27420806884766],
#  'labels': 5,
#  'scores': 0.08914941549301147}
# ================== batch ==================
# filename:  (233)www.sivanaspirit.com_5b1f.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (253)eyedictive.com_5778.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (269)pages.daraz.lk_115d.jpg
# outputs
# [{'boxes': tensor([[308.8353,  76.6825, 324.6317, 137.4704]]),
#   'labels': tensor([1]),
#   'scores': tensor([0.1267])}]
# inference result
# {'boxes': [308.8352966308594,
#            76.68246459960938,
#            324.6317138671875,
#            137.4704132080078],
#  'labels': 1,
#  'scores': 0.12665331363677979}
# ================== batch ==================
# filename:  (27)puffy.com_f607.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (273)shapermint.com_35e5.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (274)shapermint.com_ddea.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (275)shapermint.com_b425.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (299)www.autogeek.net_249b.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (305)www.bellamihair.com_5eea.jpg
# outputs
# [{'boxes': tensor([[  7.5527, 203.9850,  37.1580, 218.4616],
#         [  6.9186, 204.2314,  38.6153, 218.6313]]),
#   'labels': tensor([5, 4]),
#   'scores': tensor([0.3328, 0.0787])}]
# inference result
# {'boxes': [7.552682399749756,
#            203.98504638671875,
#            37.157981872558594,
#            218.4615936279297],
#  'labels': 5,
#  'scores': 0.33278563618659973}
# ================== batch ==================
# filename:  (334)www.fanatics.com_cceb.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (337)www.floryday.com_3f1c.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (340)www.forzieri.com_0192.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (345)www.harveynorman.com.sg_3146.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (35)shapermint.com_d46f.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (359)www.jjshouse.com_30a7.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (360)www.jjshouse.com_7293.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (383)www.mlsstore.com_7245.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (42)speedcubeshop.com_440a.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (449)www.victorianplumbing.co.uk_7777.jpg
# outputs
# [{'boxes': tensor([[173.9165, 177.9060, 239.6720, 210.3420],
#         [154.0554, 166.4841, 254.2983, 210.3792]]),
#   'labels': tensor([5, 5]),
#   'scores': tensor([0.9724, 0.6618])}]
# inference result
# {'boxes': [173.91648864746094,
#            177.906005859375,
#            239.6719970703125,
#            210.34202575683594],
#  'labels': 5,
#  'scores': 0.97244793176651}
# ================== batch ==================
# filename:  (511)www.yesstyle.com_86d6.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (539)www.homewetbar.com_3dec.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (552)www.penningtons.com_6870.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (612)store.yitechnology.com_d93e.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (657)www.ashleystewart.com_8285.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (662)www.bcbg.com_a8d3.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (688)www.chicwish.com_4cb6.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (69)www.crossrope.com_6d43.jpg
# outputs
# [{'boxes': tensor([[ 84.3374,  80.0936, 191.3158,  97.9754],
#         [ 82.4150,  80.7484, 195.1597,  98.4530]]),
#   'labels': tensor([5, 4]),
#   'scores': tensor([0.7808, 0.0770])}]
# inference result
# {'boxes': [84.33735656738281,
#            80.09358215332031,
#            191.31581115722656,
#            97.97535705566406],
#  'labels': 5,
#  'scores': 0.7807731628417969}
# ================== batch ==================
# filename:  (708)www.ebay.ca_d3e8.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (723)www.faithful-to-nature.co.za_9b6f.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (728)www.finditparts.com_f582.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (782)www.levenger.com_33f7.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (807)www.naturehills.com_bf06.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (861)www.roamans.com_9eec.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (862)www.roamans.com_03b3.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (89)www.harveynorman.com.sg_bb02.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (894)www.templeandwebster.com.au_02e7.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (921)www.wolfandbadger.com_c9c9.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (922)www.wolfandbadger.com_6799.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (931)www.zzounds.com_68a4.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (94)www.hotter.com_dcde.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  (963)www.smokecartel.com_6342.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  10000.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  10002.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  10003.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  10004.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  10005.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  10011.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  10012.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  10013.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  10014.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  10018.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  10019.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  10020.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  10021.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  10024.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  10025.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  10026.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  10027.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  10028.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  10029.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  10030.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  101.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  10277_92JZ8UO.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  103.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  10311.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  10345.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  104.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  10433.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  10447_lXAva8J.jpg
# outputs
# [{'boxes': tensor([[ 80.3481,  43.1061, 143.7743, 133.5338]]),
#   'labels': tensor([3]),
#   'scores': tensor([0.1689])}]
# inference result
# {'boxes': [80.34806060791016,
#            43.106109619140625,
#            143.77432250976562,
#            133.53378295898438],
#  'labels': 3,
#  'scores': 0.16890792548656464}
# ================== batch ==================
# filename:  1047_cgX7FtX.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1048.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  10480.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  105.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1050.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1051.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1052.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  10523_QKPfcOY.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1053.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1054.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1055.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1056.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1057.jpg
# outputs
# [{'boxes': tensor([[ 18.4180, 107.3732, 210.1543, 331.9385]]),
#   'labels': tensor([2]),
#   'scores': tensor([0.0635])}]
# inference result
# {'boxes': [18.41802978515625,
#            107.37321472167969,
#            210.15428161621094,
#            331.93853759765625],
#  'labels': 2,
#  'scores': 0.06352300941944122}
# ================== batch ==================
# filename:  1058.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1059.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  106.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  107.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  10710_iKhZ3vS.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1073.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  10779_TpFqdCn.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  10791_e5jsjLi.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  108.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1081_oljYHz2.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  10863_qaGZOUa.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1089.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1091.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1092.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1093.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1094.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1095.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1096.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1097.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  10974_07UoQn9.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1098.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1099.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  110.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1100.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1101.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1102.jpg
# outputs
# [{'boxes': tensor([[105.0947,  77.0311, 170.0547, 125.3491],
#         [103.5857,  77.9985, 170.7903, 125.8096]]),
#   'labels': tensor([5, 4]),
#   'scores': tensor([0.1892, 0.1655])}]
# inference result
# {'boxes': [105.09467315673828,
#            77.0311279296875,
#            170.05465698242188,
#            125.34905242919922],
#  'labels': 5,
#  'scores': 0.18923726677894592}
# ================== batch ==================
# filename:  1103.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1104.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1105.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1106.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1107.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1108.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  111.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1110.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1111.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1112.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1114.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1115.jpg
# outputs
# [{'boxes': tensor([[105.0974,  77.0385, 170.0928, 125.3465],
#         [103.5826,  78.0033, 170.8481, 125.8072]]),
#   'labels': tensor([5, 4]),
#   'scores': tensor([0.1914, 0.1672])}]
# inference result
# {'boxes': [105.09741973876953,
#            77.03852081298828,
#            170.0928192138672,
#            125.3464584350586],
#  'labels': 5,
#  'scores': 0.19142112135887146}
# ================== batch ==================
# filename:  1116.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1117.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1118.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1119_Kq1ZthC.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  112.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1120.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  11203_zZ33eBw.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1121.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1123.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1126.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1127.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  113.jpg
# outputs
# [{'boxes': tensor([[156.9385, 182.7674, 199.1764, 197.1524],
#         [157.8402, 182.6185, 197.7479, 196.8592]]),
#   'labels': tensor([4, 5]),
#   'scores': tensor([0.3854, 0.3305])}]
# inference result
# {'boxes': [156.93850708007812,
#            182.76739501953125,
#            199.17642211914062,
#            197.15237426757812],
#  'labels': 4,
#  'scores': 0.3854266107082367}
# ================== batch ==================
# filename:  11308_RDx6GWa.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1137_H9zzoUq.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  114.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  115.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  11510_8rRqbWu.jpg
# outputs
# [{'boxes': tensor([[ 81.5290, 192.4031, 145.0957, 211.0728]]),
#   'labels': tensor([5]),
#   'scores': tensor([0.0855])}]
# inference result
# {'boxes': [81.5290298461914,
#            192.40306091308594,
#            145.09567260742188,
#            211.0727996826172],
#  'labels': 5,
#  'scores': 0.0855412408709526}
# ================== batch ==================
# filename:  116.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  11607.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  117.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  118.jpg
# outputs
# [{'boxes': tensor([[157.1108, 226.5734, 198.8466, 241.8127],
#         [158.2968, 226.5577, 197.9466, 241.5594]]),
#   'labels': tensor([4, 5]),
#   'scores': tensor([0.5888, 0.2252])}]
# inference result
# {'boxes': [157.11077880859375,
#            226.57342529296875,
#            198.8466339111328,
#            241.81268310546875],
#  'labels': 4,
#  'scores': 0.5887901186943054}
# ================== batch ==================
# filename:  119.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1202_WEBRHD8.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  12095_yW0sLPR.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  120_x3lPqOA.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1211_FIlYrck.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  121_FKJpDve.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  12247_Lb9PIqo.jpg
# outputs
# [{'boxes': tensor([[ 94.8952, 133.3693, 129.9009, 167.8210]]),
#   'labels': tensor([4]),
#   'scores': tensor([0.6702])}]
# inference result
# {'boxes': [94.8952407836914,
#            133.36929321289062,
#            129.90090942382812,
#            167.82098388671875],
#  'labels': 4,
#  'scores': 0.6701783537864685}
# ================== batch ==================
# filename:  12257_vqzq0Bo.jpg
# outputs
# [{'boxes': tensor([[ 85.5294, 292.1762, 141.5322, 309.5356]]),
#   'labels': tensor([5]),
#   'scores': tensor([0.0920])}]
# inference result
# {'boxes': [85.52938842773438,
#            292.17620849609375,
#            141.5321807861328,
#            309.5355529785156],
#  'labels': 5,
#  'scores': 0.09199408441781998}
# ================== batch ==================
# filename:  12284.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1238_IpgL3JU.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  12415_GItLyhQ.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1245_29sppkP.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  12468_3G5DUfg.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  12616_jL97srp.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  12630_IpyePZz.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  12681_ewXNkw8.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  12733.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  12782_BrQOkOg.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  12793_gncSTUR.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  12810_9mifsrp.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  12814_ZTYnBV1.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1295_4P0AAGr.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  12978.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  12990.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  12991.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  13054_R8ibHD7.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  13068_E9D1V7w.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  13121.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  1312_L8Kt9wc.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  13179.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  13374_kzWD8xj.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  13391_TtUKOAA.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
# ...
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  music_21--TuneIn-Radio-3-24_7184.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  music_22--Starmaker-0-20_1d76.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  music_22--Starmaker-3-4_fbeb.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  music_22--Starmaker-3-8_27d0.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  music_22--Starmaker-8-1_9e27.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  music_23--Tidal-2-6_4894.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  music_24--Simple-Radio-0-20_589f.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  music_24--Simple-Radio-0-8_df32.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  music_24--Simple-Radio-3-37_c44c.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  music_24--Simple-Radio-5-40_508d.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  music_27--Groovepad-1-32_8006.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  music_29--Sticher-0-52_6901.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  music_3--Drum-Pad-0-33_8b90.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  music_3--Drum-Pad-2-26_de54.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  music_3--Drum-Pad-8-18_cf3e.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  music_30--Music-Bass-Equalizer-0-12_24d3.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  music_30--Music-Bass-Equalizer-0-6_6cef.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  music_4--SounCloud-0-46-snap3_0d6c.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  music_6--MP3-Music-Downloader-_-Free-Music-Download-0-14_4df9.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  music_6--MP3-Music-Downloader-_-Free-Music-Download-0-57_b85e.jpg
# outputs
# [{'boxes': tensor([[ 27.2097, 249.9975, 110.6859, 285.5694],
#         [ 28.4014, 254.8022, 108.0323, 281.8295]]),
#   'labels': tensor([3, 5]),
#   'scores': tensor([0.5102, 0.0692])}]
# inference result
# {'boxes': [27.209728240966797,
#            249.9974822998047,
#            110.6859130859375,
#            285.56939697265625],
#  'labels': 3,
#  'scores': 0.5101668238639832}
# ================== batch ==================
# filename:  music_8--Free-Music-Unlimited-Offline-0-13_9865.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  music_8--Free-Music-Unlimited-Offline-0-3_618f.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  music_8--Free-Music-Unlimited-Offline-4-17_3cb5.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  music_8--Free-Music-Unlimited-Offline-5-2_b930.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  music_9--AudioMack-0-24_dcf6.jpg
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  mxstore.com.au.png
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  myfave.com.png
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  nutrabay.com.png
# outputs
# [{'boxes': tensor([[ 53.1029,  42.2952, 100.7725,  57.6075]]),
#   'labels': tensor([5]),
#   'scores': tensor([0.2474])}]
# inference result
# {'boxes': [53.102928161621094,
#            42.295162200927734,
#            100.77250671386719,
#            57.60749435424805],
#  'labels': 5,
#  'scores': 0.247433140873909}
# ================== batch ==================
# filename:  organicaromas.com.png
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  platt.com.png
# outputs
# [{'boxes': tensor([[ 92.8872,  52.9983, 168.6152, 120.1940]]),
#   'labels': tensor([5]),
#   'scores': tensor([0.9891])}]
# inference result
# {'boxes': [92.88716125488281,
#            52.99833679199219,
#            168.61521911621094,
#            120.19398498535156],
#  'labels': 5,
#  'scores': 0.9891021251678467}
# ================== batch ==================
# filename:  secure.mdg.com.png
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  shapermint.com.png
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  shop.iravin.com.png
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  shop.ozobot.com.png
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  speedcubeshop.com.png
# outputs
# [{'boxes': tensor([[120.2253, 111.2688, 154.1154, 134.4091],
#         [119.8363, 111.4577, 155.4941, 135.0865]]),
#   'labels': tensor([5, 4]),
#   'scores': tensor([0.3629, 0.2294])}]
# inference result
# {'boxes': [120.22533416748047,
#            111.26880645751953,
#            154.11537170410156,
#            134.40911865234375],
#  'labels': 5,
#  'scores': 0.36289381980895996}
# ================== batch ==================
# filename:  stock-optimization.png
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  ttdeye.com.png
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  urbanedcsupply.com.png
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  us.pandora.net.png
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  victoriaplum.com.png
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  www.1800flowers.com.png
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  www.aafnation.com.png
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  www.adoreme.com.png
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  www.airydress.com.png
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  www.autogeek.net.png
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  www.bonescoffee.com.png
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  www.colorsbridesmaid.com.png
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  www.dreamcloudsleep.com.png
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  www.gasbike.net.png
# outputs
# [{'boxes': tensor([[176.8451, 100.9090, 214.7289, 110.7401]]),
#   'labels': tensor([4]),
#   'scores': tensor([0.0812])}]
# inference result
# {'boxes': [176.84506225585938,
#            100.90898132324219,
#            214.7289276123047,
#            110.7401351928711],
#  'labels': 4,
#  'scores': 0.08124832063913345}
# ================== batch ==================
# filename:  www.geekbuying.com.png
# outputs
# [{'boxes': tensor([[322.7204,  66.7211, 355.4453,  88.2759],
#         [ 79.2340, 149.3744, 173.1132, 186.0305],
#         [321.8865,  67.1057, 357.1847,  88.7912]]),
#   'labels': tensor([5, 5, 4]),
#   'scores': tensor([0.4751, 0.2987, 0.2030])}]
# inference result
# {'boxes': [322.7203674316406,
#            66.72111511230469,
#            355.44525146484375,
#            88.27590942382812],
#  'labels': 5,
#  'scores': 0.47514861822128296}
# ================== batch ==================
# filename:  www.myphotosocks.com.png
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  www.selectblinds.com.png
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  www.stealthangelsurvival.com.png
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  www.thertastore.com.png
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}
# ================== batch ==================
# filename:  www.uksoccershop.com.png
# outputs
# [{'boxes': tensor([[293.2461, 129.1073, 308.4908, 144.2030]]),
#   'labels': tensor([4]),
#   'scores': tensor([0.0587])}]
# inference result
# {'boxes': [293.2460632324219,
#            129.1072998046875,
#            308.4907531738281,
#            144.20298767089844],
#  'labels': 4,
#  'scores': 0.0586995929479599}
# ================== batch ==================
# filename:  www.wowcher.co.uk.png
# outputs
# [{'boxes': tensor([], size=(0, 4)),
#   'labels': tensor([], dtype=torch.int64),
#   'scores': tensor([])}]
# inference result
# {'boxes': None, 'labels': None, 'scores': None}

# %%
# # write inference result
# with open('./inference_result.json', 'w') as fp:
#   json.dump(inference_result, fp)
